# %% [markdown]
# ## Introduction
# Delfi Kusuma Wardhani
#
# H8 FTDS - 002

# %% [markdown]
# ## Assignment Instructions
#
# - Unduh dataset yang akan dipakai [disini](https://www.kaggle.com/hendratno/covid19-indonesia).
# - Cari Measure of Central Tendency dari data tersebut.
# - Cari Measure of Variance dari data tersebut.

# %% [markdown]
# ## Dataset Description
# The COVID-19 pandemic dataset in Indonesia, time series. This dataset is a compilation of various open data sources, including: covid19.go.id (pandemic data), kemendagri.go.id (demographic data), bps.go.id (demographic data), as well as some calculations of the relationship of the data.
#
# This dataset contains a time series of COVID-19 pandemic events in Indonesia, at the country level to province level. If possible, in the future I will provide it to the city/regency level.

# %% [markdown]
# ## Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from scipy.stats import t as t_func
from scipy.stats import norm
from scipy.stats import kurtosis

# %% [markdown]
# ## Data Loading

# %%
df = pd.read_csv('covid_19_indonesia_time_series_all.csv')
df
# Out:
#             Date Location ISO Code           Location  New Cases  New Deaths  \
# 0       1/8/2020             ID-JI         Jawa Timur          9           3
# 1       1/9/2020             ID-JI         Jawa Timur          0           1
# 2      1/10/2020             ID-JI         Jawa Timur          0           1
# 3      1/11/2020             ID-JI         Jawa Timur          0           3
# 4      1/12/2020             ID-JI         Jawa Timur          0           3
# ...          ...               ...                ...        ...         ...
# 16278   7/9/2021             ID-SG  Sulawesi Tenggara        124           1
# 16279   7/9/2021             ID-SA     Sulawesi Utara        278           9
# 16280   7/9/2021             ID-SB     Sumatera Barat        718          10
# 16281   7/9/2021             ID-SS   Sumatera Selatan        341           6
# 16282   7/9/2021             ID-SU     Sumatera Utara        336           5
#
# ...

# %% [markdown]
# ## Data Preprocessing

# %%
df.isnull().sum()
# Out:
# Date                               0
# Location ISO Code                  0
# Location                           0
# New Cases                          0
# New Deaths                         0
# New Recovered                      0
# New Active Cases                   0
# Total Cases                        0
# Total Deaths                       0
# Total Recovered                    0
# Total Active Cases                 0
# Location Level                     0
# City or Regency                16283
# Province                         495
# Country                            0
# Continent                          0
# Island                           495
# Time Zone                        495
# Special Status                 13890
# Total Regencies                    0
# Total Cities                     469
# Total Districts                    0
# Total Urban Villages             471
# Total Rural Villages             496
# Area (km2)                         0
# ...

# %%
hapus = ['City or Regency','Name','Item', 'Kind', 'Hidden', 'Special Status', 
'New Cases per Million', 'Total Cases per Million', 'New Deaths per Million',
'Total Deaths per Million','Longitude','Latitude']
df.drop(hapus, axis=1, inplace=True)
df
# Out:
#             Date Location ISO Code           Location  New Cases  New Deaths  \
# 0       1/8/2020             ID-JI         Jawa Timur          9           3
# 1       1/9/2020             ID-JI         Jawa Timur          0           1
# 2      1/10/2020             ID-JI         Jawa Timur          0           1
# 3      1/11/2020             ID-JI         Jawa Timur          0           3
# 4      1/12/2020             ID-JI         Jawa Timur          0           3
# ...          ...               ...                ...        ...         ...
# 16278   7/9/2021             ID-SG  Sulawesi Tenggara        124           1
# 16279   7/9/2021             ID-SA     Sulawesi Utara        278           9
# 16280   7/9/2021             ID-SB     Sumatera Barat        718          10
# 16281   7/9/2021             ID-SS   Sumatera Selatan        341           6
# 16282   7/9/2021             ID-SU     Sumatera Utara        336           5
#
# ...

# %%
df.isnull().sum()
# Out:
# Date                              0
# Location ISO Code                 0
# Location                          0
# New Cases                         0
# New Deaths                        0
# New Recovered                     0
# New Active Cases                  0
# Total Cases                       0
# Total Deaths                      0
# Total Recovered                   0
# Total Active Cases                0
# Location Level                    0
# Province                        495
# Country                           0
# Continent                         0
# Island                          495
# Time Zone                       495
# Total Regencies                   0
# Total Cities                    469
# Total Districts                   0
# Total Urban Villages            471
# Total Rural Villages            496
# Area (km2)                        0
# Population                        0
# Population Density                0
# Case Fatality Rate                0
# ...

# %%
df.fillna('Unknown', inplace=True)

# %%
df.isnull().sum()
# Out:
# Date                           0
# Location ISO Code              0
# Location                       0
# New Cases                      0
# New Deaths                     0
# New Recovered                  0
# New Active Cases               0
# Total Cases                    0
# Total Deaths                   0
# Total Recovered                0
# Total Active Cases             0
# Location Level                 0
# Province                       0
# Country                        0
# Continent                      0
# Island                         0
# Time Zone                      0
# Total Regencies                0
# Total Cities                   0
# Total Districts                0
# Total Urban Villages           0
# Total Rural Villages           0
# Area (km2)                     0
# Population                     0
# Population Density             0
# Case Fatality Rate             0
# Case Recovered Rate            0
# Growth Factor of New Cases     0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16283 entries, 0 to 16282
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         16283 non-null  object
#  1   Location ISO Code            16283 non-null  object
#  2   Location                     16283 non-null  object
#  3   New Cases                    16283 non-null  int64
#  4   New Deaths                   16283 non-null  int64
#  5   New Recovered                16283 non-null  int64
#  6   New Active Cases             16283 non-null  int64
#  7   Total Cases                  16283 non-null  int64
#  8   Total Deaths                 16283 non-null  int64
#  9   Total Recovered              16283 non-null  int64
#  10  Total Active Cases           16283 non-null  int64
#  11  Location Level               16283 non-null  object
#  12  Province                     16283 non-null  object
# ...

# %% [markdown]
# ## Data Exploration

# %%
b = df.groupby('Location')[['New Cases']].sum()
b
# Out:
#                             New Cases
# Location
# Aceh                            20140
# Bali                            54079
# Banten                          61689
# Bengkulu                        11671
# DKI Jakarta                    636346
# Daerah Istimewa Yogyakarta      72560
# Indonesia                     2455912
# Jambi                           13935
# Jawa Barat                     440379
# Jawa Tengah                    285348
# Jawa Timur                     189705
# Kalimantan Barat                16811
# Kalimantan Selatan              37176
# Kalimantan Tengah               27808
# Kalimantan Timur                83762
# Kalimantan Utara                14274
# Kepulauan Bangka Belitung       23188
# Kepulauan Riau                  30637
# Lampung                         24378
# Maluku                          10465
# Maluku Utara                     6526
# Nusa Tenggara Barat             13466
# Nusa Tenggara Timur             22933
# ...

# %%
df_baru = df[['Date','Location','New Cases','New Deaths', 'New Recovered','Population','Population Density','Case Fatality Rate']]
df_baru
# Out:
#             Date           Location  New Cases  New Deaths  New Recovered  \
# 0       1/8/2020         Jawa Timur          9           3              1
# 1       1/9/2020         Jawa Timur          0           1             23
# 2      1/10/2020         Jawa Timur          0           1             14
# 3      1/11/2020         Jawa Timur          0           3              8
# 4      1/12/2020         Jawa Timur          0           3              1
# ...          ...                ...        ...         ...            ...
# 16278   7/9/2021  Sulawesi Tenggara        124           1              3
# 16279   7/9/2021     Sulawesi Utara        278           9              9
# 16280   7/9/2021     Sumatera Barat        718          10            275
# 16281   7/9/2021   Sumatera Selatan        341           6            221
# 16282   7/9/2021     Sumatera Utara        336           5            241
#
#        Population  Population Density Case Fatality Rate
# ...

# %%
df_baru.describe()
# Out:
#           New Cases    New Deaths  New Recovered    Population  \
# count  16283.000000  16283.000000   16283.000000  1.628300e+04
# mean     301.271879      7.919364     248.015783  1.605704e+07
# std     1330.028199     32.171434     997.784905  4.546363e+07
# min        0.000000      0.000000       0.000000  6.484070e+05
# 25%        6.000000      0.000000       2.000000  2.570289e+06
# 50%       39.000000      1.000000      24.000000  4.340348e+06
# 75%      127.000000      4.000000     106.000000  9.095591e+06
# max    38391.000000   1040.000000   28975.000000  2.651855e+08
#
#        Population Density
# count        16283.000000
# mean           768.308731
# std           2784.573161
# min              8.590000
# 25%             47.790000
# 50%            103.840000
# 75%            262.700000
# max          16334.310000

# %% [markdown]
# ## Measure of Variance

# %%
df_baru.groupby('Location').sum()
# Out:
#                             New Cases  New Deaths  New Recovered  \
# Location
# Aceh                            20140         862          15534
# Bali                            54079        1618          46180
# Banten                          61689        1452          50392
# Bengkulu                        11671         194           9530
# DKI Jakarta                    636346        9250         526921
# Daerah Istimewa Yogyakarta      72560        1892          54220
# Indonesia                     2455912       64631        2023548
# Jambi                           13935         284          11892
# Jawa Barat                     440379        6008         348619
# Jawa Tengah                    285348       12553         223689
# Jawa Timur                     189705       13633         160287
# Kalimantan Barat                16811         411          14370
# Kalimantan Selatan              37176        1091          34774
# ...

# %%
df_baru.corr()
# Out:
#                     New Cases  New Deaths  New Recovered  Population  \
# New Cases            1.000000    0.923413       0.919865    0.632065
# New Deaths           0.923413    1.000000       0.897754    0.696282
# New Recovered        0.919865    0.897754       1.000000    0.693295
# Population           0.632065    0.696282       0.693295    1.000000
# Population Density   0.137188    0.069342       0.151009   -0.005549
#
#                     Population Density
# New Cases                     0.137188
# New Deaths                    0.069342
# New Recovered                 0.151009
# Population                   -0.005549
# Population Density            1.000000

# %%
# Standard deviation
print("Numeric columns Standard Deviation")
print(df_baru.std())
print("")
print("Numeric columns Variance")
print(df_baru.var())
print("")
#Range
num_columns = df_baru.describe().columns
print(df_baru[num_columns].max()-df_baru[num_columns].min())
# Out:
# Numeric columns Standard Deviation
# New Cases             1330.028199
# New Deaths              32.171434
# New Recovered          997.784905
# Population Density    2784.573161
# dtype: float64
#
# Numeric columns Variance
# New Cases             1.768975e+06
# New Deaths            1.035001e+03
# New Recovered         9.955747e+05
# Population Density    7.753848e+06
# dtype: float64
#
# New Cases             38391.00
# New Deaths             1040.00
# New Recovered         28975.00
# Population Density    16325.72
# dtype: float64
